# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import emoji
import jaconv
import collections
import MeCab

# %%
cd ../
# Out:
# C:\Users\akite\OneDrive\デスクトップ\source code\twitter-compe

# %%
df = pd.read_csv('./arranged_data/wakati.csv')

# %%
df
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     id  flg  keyword  \
# 0               0             0               0  20587    0      覚醒剤
# 1               1             1               1  31857    0     雷 落雷
# 2               2             2               2  36793    0       血液
# 3               3             3               3  42299    0    ハリケーン
# 4               4             4               4  51449    0      殺人鬼
# ...           ...           ...             ...    ...  ...      ...
# 20280       20280         20280           20280  45367    0     爆発した
# 20281       20281         20281           20281  45546    0     爆発した
# 20282       20282         20282           20282  31532    0       爆発
# 20283       20283         20283           20283  21619    0  緊急 緊急事態
# 20284       20284         20284           20284  25999    0       炎上
#
#                   location                                               text  \
# 0              icon:大トロ( )                        【ﾏｲﾘｽﾄ】ｶｶｶｶ覚醒剤  #sm36302050
# 1                    ジャングル        せやな 落雷撃たれたら全員張り付くしかなかったからなぁ なんで速攻で雷銅狙いに行ったわ
# 2        ↓↓↓↓↓こちらをクリック↓↓↓↓  【ｶﾌｪｲﾝの力】 体を動かす前にｶﾌｪｲﾝを摂ると交感神経が刺激され､体内の脂肪が分解され...
# 3      Close to your heart  あなたの鼓膜に直に響かせたい ﾊﾘｹｰﾝのように激しく愛したい 余計な壁なんて取っ払って 奥...
# 4               偽物なので悪しからず   違う違う｡お化けは現実にいないけど殺人鬼は現実にいるじゃん〜｡うｰん､ﾎﾗｰってなると難し...
# ...                    ...                                                ...
# 20280                  NaN   まだ爆発したかはわかりません｡ 一つだけ言えることは､もうすぐ(数万年以内に)爆発するとい...
# 20281           🐒🐟 ✩͓̊  🌊🐷                  ぴこち愛爆発した ｡ ぴこちぴこちぴこちいいいいいい 愛してる❤︎
# 20282                Japan  今のﾛｰﾃ環境､重要度で言うと 序盤からﾃﾝﾎﾟを取る動き<進化t以降に爆発的な動き だって...
# 20283                  NaN   代議士先生  これは一般国民の意見が耳障りだから と言う理由での恫喝ですよね?  緊急事態...
# 20284               日本のどこか               炎上型ｻﾖｸｼﾞｬｰﾅﾘｽﾄw どんな肝炎だろ｡寡聞にして知らんけど｡
#
#        is_url  is_location  num_emoji  num_reply  num_hash  text_length  \
# 0        True        False        0.0          0         1         50.0
# 1       False        False        0.0          1         0         59.0
# 2       False        False        0.0          0         0        139.0
# 3       False        False        0.0          0         0        119.0
# 4       False        False        0.0          1         0        146.0
# ...       ...          ...        ...        ...       ...          ...
# 20280   False         True        0.0          1         0        101.0
# 20281   False        False        1.0          1         0         42.0
# 20282   False        False        0.0          0         0        138.0
# 20283   False         True        0.0          1         0        102.0
# 20284    True        False        0.0          0         0         58.0
#
#                                              text_wakati  num_kusa
# 0      ['【', 'ﾏｲﾘｽﾄ', '】', 'ｶｶｶｶ', '覚醒剤', '  ', '#', ...         0
# 1      ['する', 'や', 'な', ' ', '落雷', '撃つ', 'れる', 'た', '...         0
# 2      ['【', 'ｶﾌｪｲﾝ', 'の', '力', '】', ' ', '体', 'を', '...         0
# 3      ['あなた', 'の', '鼓膜', 'に', '直に', '響かせる', 'たい', ' ...         0
# 4      ['違う', '違う', '｡', 'お化け', 'は', '現実', 'に', 'いる',...         0
# ...                                                  ...       ...
# 20280  ['まだ', '爆発', 'する', 'た', 'か', 'は', 'わかる', 'ます',...         0
# 20281  ['ぴこち', '愛', '爆発', 'する', 'た', ' ', '｡', ' ', '...         0
# 20282  ['今', 'の', 'ﾛｰﾃ', '環境', '､', '重要', '度', 'で', '...         0
# 20283  ['代議士', '先生', '  ', 'これ', 'は', '一般', '国民', 'の'...         0
# 20284  ['炎上', '型', 'ｻﾖｸｼﾞｬｰﾅﾘｽﾄ', 'w', ' ', 'どんな', '肝...         1
#
# [20285 rows x 16 columns]

# %%
termFreq = {}

for idx in range(0,df.shape[0]):
    df["text_wakati"].loc[idx] = [token.base_form for token in t.tokenize(df["text"].loc[idx])]
